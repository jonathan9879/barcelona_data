# %%
import pandas as pd

# %%
estacions_bicing = pd.read_csv('estacions_bicing.csv', sep = ';')

# %%
estacions_bicing
# Out:
#     Anys  Valor
# 0   2007    194
# 1   2008    390
# 2   2009    419
# 3   2010    420
# 4   2011    421
# 5   2012    420
# 6   2013    421
# 7   2014    420
# 8   2015    423
# 9   2016    420
# 10  2017    420

# %%
abonats_bicing = pd.read_csv('abonats_bicing.csv', sep=';', encoding = 'ISO-8859-1')

# %%
abonats_bicing
# Out:
#     Anys       Mes   Valor
# 0   2014     Anual   96252
# 1   2014     Gener       0
# 2   2014    Febrer       0
# 3   2014      Març   99401
# 4   2014     Abril   99038
# 5   2014      Maig   98382
# 6   2014      Juny   97957
# 7   2014    Juliol   97437
# 8   2014     Agost   97109
# 9   2014  Setembre   96846
# 10  2014   Octubre   96330
# 11  2014  Novembre   95886
# 12  2014  Desembre   96252
# 13  2015     Anual   95537
# 14  2015     Gener   95745
# 15  2015    Febrer   96191
# 16  2015      Març   96385
# 17  2015     Abril   95581
# 18  2015      Maig   95173
# 19  2015      Juny   95290
# 20  2015    Juliol   95116
# 21  2015     Agost   95395
# 22  2015  Setembre       0
# 23  2015   Octubre       0
# 24  2015  Novembre       0
# 25  2015  Desembre       0
# 26  2016     Anual  102353
# 27  2016     Gener   94913
# 28  2016    Febrer   96059
# 29  2016      Març   96452
# 30  2016     Abril   96583
# 31  2016      Maig   96715
# 32  2016      Juny   97573
# ...

# %%
demanda_bicing = pd.read_csv('demanda_bicing.csv', sep = ';', encoding = 'ISO-8859-1')

# %%
demanda_bicing
# Out:
#      Anys       Mes     Valor
# 0    2007     Anual   3781855
# 1    2007     Gener         0
# 2    2007    Febrer         0
# 3    2007      Març       744
# 4    2007     Abril     18684
# 5    2007      Maig    181861
# 6    2007      Juny    363399
# 7    2007    Juliol    510983
# 8    2007     Agost    452278
# 9    2007  Setembre    541646
# 10   2007   Octubre    546365
# 11   2007  Novembre    622796
# 12   2007  Desembre    543099
# 13   2008     Anual  12307828
# 14   2008     Gener    717545
# 15   2008    Febrer    775494
# 16   2008      Març    911191
# 17   2008     Abril   1120121
# 18   2008      Maig   1082011
# 19   2008      Juny   1173518
# 20   2008    Juliol   1185254
# 21   2008     Agost    984162
# 22   2008  Setembre   1182431
# 23   2008   Octubre   1212708
# 24   2008  Novembre   1036873
# 25   2008  Desembre    926520
# 26   2009     Anual  10704955
# 27   2009     Gener    965094
# 28   2009    Febrer    810471
# 29   2009      Març    983955
# ...

# %%
emisions_municipi = pd.read_csv('emissions_per_municipi_2012.csv', sep = ';', encoding = 'ISO-8859-1')

# %%
emisions_municipi
# Out:
#                          Àmbits  Anys       Contaminant  Valor
# 0                      Badalona  2012  Emissions de NO2    121
# 1                      Badalona  2012   Emissions de PM     38
# 2                     Barcelona  2012  Emissions de NO2   1052
# 3                     Barcelona  2012   Emissions de PM    322
# 4                        Begues  2012  Emissions de NO2      6
# 5                        Begues  2012   Emissions de PM      2
# 6                 Castellbisbal  2012  Emissions de NO2    107
# 7                 Castellbisbal  2012   Emissions de PM     32
# 8                 Castelldefels  2012  Emissions de NO2     47
# 9                 Castelldefels  2012   Emissions de PM     14
# 10                     Cervelló  2012  Emissions de NO2     23
# 11                     Cervelló  2012   Emissions de PM      7
# 12         Corbera de Llobregat  2012  Emissions de NO2      5
# 13         Corbera de Llobregat  2012   Emissions de PM      2
# ...
